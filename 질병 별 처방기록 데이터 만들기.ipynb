# %%
drug_max = {"ketamine":4, "diprivan_01" :3, "diprivan_02" :2, 
            "Amphetamine" :40, "phentermine" :38, "GHB":2500, 
            "Merthylphenidate":54, "zopiclone":8, "zolpidem_01":4, 
            "zolpidem_02":10, "benzodiazepine":40}

drug_ID = {"ketamine":1, "diprivan_01" :2, "diprivan_02" :3, 
           "Amphetamine" :4, "phentermine" :5, "GHB":6, 
           "Merthylphenidate":7, "zopiclone":8, "zolpidem_01":9, 
           "zolpidem_02":10, "benzodiazepine":11}

# %%
import pandas as pd
import numpy as np
prescription_record = pd.DataFrame({"patientID":[],"hosID":[],"drugID":[],"doctorID":[],"prescription_amount":[],"day":[]})
prescription_record
# Out:
# Empty DataFrame
# Columns: [patientID, hosID, drugID, doctorID, prescription_amount, day]
# Index: []

# %%
append = pd.read_csv("append.csv")
real = append.iloc[0:len(append)+1,1:3]

# %%
import datetime

# %%
start_date = pd.to_datetime('2020-01-01') ## 시작 날짜
end_date = pd.to_datetime('2023-05-23') ## 마지막 날짜
 
dates = pd.date_range(start_date,end_date,freq='D') ## 일단위로 생성
dates = dates.strftime('%Y-%m-%d')
dates
# Out:
# Index(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04', '2020-01-05',
#        '2020-01-06', '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#        ...
#        '2023-05-14', '2023-05-15', '2023-05-16', '2023-05-17', '2023-05-18',
#        '2023-05-19', '2023-05-20', '2023-05-21', '2023-05-22', '2023-05-23'],
#       dtype='object', length=1239)

# %%
## doctorID -> 2 ~ 32
## hosID -> 1 ~ 9
## patientID -> 1 ~ 100


## ketamine
num = 0
for i in range(1,21):
    for j in range(1,41):
        doctorID = np.random.randint(2,33)
        prescription_amount = np.random.randint(1,drug_max["ketamine"]+1)
        prescription_date = np.random.choice(dates)
        prescription_record.loc[num] = [j,real.iloc[doctorID-2,1],1,doctorID,prescription_amount,prescription_date]
        num += 1
        
        
## diprivan_01
for i in range(1,21):
    for j in range(41,81):
        doctorID = np.random.randint(2,33)
        prescription_amount = np.random.randint(1,drug_max["diprivan_01"]+1)
        prescription_date = np.random.choice(dates)
        prescription_record.loc[num] = [j,real.iloc[doctorID-2,1],2,doctorID,prescription_amount,prescription_date]
        num += 1
        
        
## diprivan_02
for i in range(1,21):
    for j in range(81,121):
        doctorID = np.random.randint(2,33)
        prescription_amount = np.random.randint(1,drug_max["diprivan_02"]+1)
        prescription_date = np.random.choice(dates)
        prescription_record.loc[num] = [j,real.iloc[doctorID-2,1],3,doctorID,prescription_amount,prescription_date]
        num += 1
         
        
## Amphetamine
for i in range(1,21):
    for j in range(121,161):
        doctorID = np.random.randint(2,33)
        prescription_amount = np.random.randint(1,drug_max["Amphetamine"]+1)
        prescription_date = np.random.choice(dates)
        prescription_record.loc[num] = [j,real.iloc[doctorID-2,1],4,doctorID,prescription_amount,prescription_date]
        num += 1
        
        
## phentermine
for i in range(1,21):
    for j in range(161,201):
        doctorID = np.random.randint(2,33)
        prescription_amount = np.random.randint(1,drug_max["phentermine"]+1)
        prescription_date = np.random.choice(dates)
        prescription_record.loc[num] = [j,real.iloc[doctorID-2,1],5,doctorID,prescription_amount,prescription_date]
        num += 1
        
        
## GHB
for i in range(1,21):
    for j in range(201,241):
        doctorID = np.random.randint(2,33)
        prescription_amount = np.random.randint(1,drug_max["GHB"]+1)
        prescription_date = np.random.choice(dates)
        prescription_record.loc[num] = [j,real.iloc[doctorID-2,1],6,doctorID,prescription_amount,prescription_date]
        num += 1
        
        
## Merthylphenidate
for i in range(1,21):
    for j in range(241,281):
        doctorID = np.random.randint(2,33)
        prescription_amount = np.random.randint(1,drug_max["Merthylphenidate"]+1)
        prescription_date = np.random.choice(dates)
        prescription_record.loc[num] = [j,real.iloc[doctorID-2,1],7,doctorID,prescription_amount,prescription_date]
        num += 1
        
        
## zopiclone
for i in range(1,21):
    for j in range(281,321):
        doctorID = np.random.randint(2,33)
        prescription_amount = np.random.randint(1,drug_max["zopiclone"]+1)
        prescription_date = np.random.choice(dates)
        prescription_record.loc[num] = [j,real.iloc[doctorID-2,1],8,doctorID,prescription_amount,prescription_date]
        num += 1  
        

## zolpidem_01
for i in range(1,21):
    for j in range(321,361):
        doctorID = np.random.randint(2,33)
        prescription_amount = np.random.randint(1,drug_max["zolpidem_01"]+1)
        prescription_date = np.random.choice(dates)
        prescription_record.loc[num] = [j,real.iloc[doctorID-2,1],9,doctorID,prescription_amount,prescription_date]
        num += 1  
        
        
## zolpidem_02
for i in range(1,21):
    for j in range(361,401):
        doctorID = np.random.randint(2,33)
        prescription_amount = np.random.randint(1,drug_max["zolpidem_02"]+1)
        prescription_date = np.random.choice(dates)
        prescription_record.loc[num] = [j,real.iloc[doctorID-2,1],10,doctorID,prescription_amount,prescription_date]
        num += 1  
        
        
## benzodiazepine
for i in range(1,21):
    for j in range(401,441):
        doctorID = np.random.randint(2,33)
        prescription_amount = np.random.randint(1,drug_max["benzodiazepine"]+1)
        prescription_date = np.random.choice(dates)
        prescription_record.loc[num] = [j,real.iloc[doctorID-2,1],11,doctorID,prescription_amount,prescription_date]
        num += 1        
        
        
prescription_record
# Out:
#       patientID  hosID  drugID  doctorID  prescription_amount         day
# 0             1      1       1        26                    4  2020-01-18
# 1             2      8       1        17                    1  2023-01-30
# 2             3      9       1        31                    1  2020-03-27
# 3             4      4       1         4                    4  2021-10-31
# 4             5      3       1        11                    3  2021-07-21
# ...         ...    ...     ...       ...                  ...         ...
# 8795        436      3      11         6                   28  2020-03-04
# 8796        437      2      11        23                   32  2021-12-11
# 8797        438      9      11         7                   40  2022-08-23
# 8798        439      1      11        29                   35  2022-03-18
# 8799        440      9      11        19                   28  2021-07-02
#
# [8800 rows x 6 columns]

# %%
prescription_record.to_csv("C:\\Users\\mingu\\Desktop\\real_prescription.csv")
